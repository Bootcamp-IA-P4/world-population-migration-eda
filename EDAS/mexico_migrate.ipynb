# %% [markdown]
# ## EDA Migración de México debido al narcotráfico

# %% [markdown]
# ### 1. Importación de Librerías y carga de datos

# %%
import pandas as pd
import numpy as np

# Importamos librerias para visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Configuramos las gráficas
plt.style.use('seaborn-v0_8') 

# Configurar pandas para mostrar números completos sin notación científica
pd.set_option('display.float_format', '{:.0f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %% [markdown]
# ### 1.2 Carga de los Dataset

# %%
# Carga el archivo CSV en un Dataframe de (Población mundial)
df_world = pd.read_csv('../data/world_population_long.csv')
print(f"El DataFrame World Population tiene {df_world.shape[0]} filas y {df_world.shape[1]} columnas.")
# Out:
# El DataFrame World Population tiene 16758 filas y 3 columnas.

# %%
df_crime = pd.read_csv('../data/crime.csv')
print(f"El DataFrame Mexico crime rate statistics  tiene {df_crime.shape[0]} filas y {df_crime.shape[1]} columnas.")

df_immigration = pd.read_csv('../data/mexico_immigration.csv')
print(f"El DataFrame mexico immigration tiene {df_immigration.shape[0]} filas y {df_immigration.shape[1]} columnas.")
# Out:
# El DataFrame Mexico crime rate statistics  tiene 266 filas y 69 columnas.
# El DataFrame mexico immigration tiene 266 filas y 69 columnas.

# %% [markdown]
# ### 1.3. Información de los DataFrame

# %%
df_world.info()
print("\n" + "-"*50 + "\n") 

df_crime.info()
print("\n" + "-"*50 + "\n")

df_immigration.info()
print("\n" + "-"*50 + "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16758 entries, 0 to 16757
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  16758 non-null  object
#  1   Year          16758 non-null  int64
#  2   Population    16758 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 392.9+ KB
#
# --------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            0 non-null      float64
#  5   1961            0 non-null      float64
#  6   1962            0 non-null      float64
#  7   1963            0 non-null      float64
#  8   1964            0 non-null      float64
#  9   1965            0 non-null      float64
#  10  1966            0 non-null      float64
#  11  1967            0 non-null      float64
#  12  1968            0 non-null      float64
#  13  1969            0 non-null      float64
#  14  1970            0 non-null      float64
#  15  1971            0 non-null      float64
#  16  1972            0 non-null      float64
#  17  1973            0 non-null      float64
#  18  1974            0 non-null      float64
#  19  1975            0 non-null      float64
#  20  1976            0 non-null      float64
#  21  1977            0 non-null      float64
#  22  1978            0 non-null      float64
#  23  1979            0 non-null      float64
#  24  1980            0 non-null      float64
#  25  1981            0 non-null      float64
#  26  1982            0 non-null      float64
#  27  1983            0 non-null      float64
#  28  1984            0 non-null      float64
#  29  1985            0 non-null      float64
#  30  1986            0 non-null      float64
#  31  1987            0 non-null      float64
#  32  1988            0 non-null      float64
#  33  1989            0 non-null      float64
#  34  1990            94 non-null     float64
#  35  1991            90 non-null     float64
#  36  1992            95 non-null     float64
#  37  1993            94 non-null     float64
#  38  1994            101 non-null    float64
#  39  1995            103 non-null    float64
#  40  1996            102 non-null    float64
#  41  1997            105 non-null    float64
#  42  1998            104 non-null    float64
#  43  1999            109 non-null    float64
#  44  2000            122 non-null    float64
#  45  2001            132 non-null    float64
#  46  2002            134 non-null    float64
#  47  2003            117 non-null    float64
#  48  2004            131 non-null    float64
#  49  2005            127 non-null    float64
#  50  2006            134 non-null    float64
#  51  2007            147 non-null    float64
#  52  2008            157 non-null    float64
#  53  2009            154 non-null    float64
#  54  2010            171 non-null    float64
#  55  2011            161 non-null    float64
#  56  2012            198 non-null    float64
#  57  2013            142 non-null    float64
#  58  2014            175 non-null    float64
#  59  2015            180 non-null    float64
#  60  2016            145 non-null    float64
#  61  2017            145 non-null    float64
#  62  2018            140 non-null    float64
#  63  2019            147 non-null    float64
#  64  2020            138 non-null    float64
#  65  2021            115 non-null    float64
#  66  2022            0 non-null      float64
#  67  2023            0 non-null      float64
#  68  Unnamed: 68     0 non-null      float64
# dtypes: float64(65), object(4)
# memory usage: 143.5+ KB
#
# --------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            265 non-null    float64
#  5   1961            265 non-null    float64
#  6   1962            265 non-null    float64
#  7   1963            265 non-null    float64
#  8   1964            265 non-null    float64
#  9   1965            265 non-null    float64
#  10  1966            265 non-null    float64
#  11  1967            265 non-null    float64
#  12  1968            265 non-null    float64
#  13  1969            265 non-null    float64
#  14  1970            265 non-null    float64
#  15  1971            265 non-null    float64
#  16  1972            265 non-null    float64
#  17  1973            265 non-null    float64
#  18  1974            265 non-null    float64
#  19  1975            265 non-null    float64
#  20  1976            265 non-null    float64
#  21  1977            265 non-null    float64
#  22  1978            265 non-null    float64
#  23  1979            265 non-null    float64
#  24  1980            265 non-null    float64
#  25  1981            265 non-null    float64
#  26  1982            265 non-null    float64
#  27  1983            265 non-null    float64
#  28  1984            265 non-null    float64
#  29  1985            265 non-null    float64
#  30  1986            265 non-null    float64
#  31  1987            265 non-null    float64
#  32  1988            265 non-null    float64
#  33  1989            265 non-null    float64
#  34  1990            265 non-null    float64
#  35  1991            265 non-null    float64
#  36  1992            265 non-null    float64
#  37  1993            265 non-null    float64
#  38  1994            265 non-null    float64
#  39  1995            265 non-null    float64
#  40  1996            265 non-null    float64
#  41  1997            265 non-null    float64
#  42  1998            265 non-null    float64
#  43  1999            265 non-null    float64
#  44  2000            265 non-null    float64
#  45  2001            265 non-null    float64
#  46  2002            265 non-null    float64
#  47  2003            265 non-null    float64
#  48  2004            265 non-null    float64
#  49  2005            265 non-null    float64
#  50  2006            265 non-null    float64
#  51  2007            265 non-null    float64
#  52  2008            265 non-null    float64
#  53  2009            265 non-null    float64
#  54  2010            265 non-null    float64
#  55  2011            265 non-null    float64
#  56  2012            265 non-null    float64
#  57  2013            265 non-null    float64
#  58  2014            265 non-null    float64
#  59  2015            265 non-null    float64
#  60  2016            265 non-null    float64
#  61  2017            265 non-null    float64
#  62  2018            265 non-null    float64
#  63  2019            265 non-null    float64
#  64  2020            265 non-null    float64
#  65  2021            265 non-null    float64
#  66  2022            265 non-null    float64
#  67  2023            265 non-null    float64
#  68  Unnamed: 68     0 non-null      float64
# dtypes: float64(65), object(4)
# memory usage: 143.5+ KB
#
# --------------------------------------------------

# %% [markdown]
# ### 1.4. Visualizacion de las primeras 10 filas de cada tabla

# %%
df_world.head()
# Out:
#   Country Name  Year  Population
# 0  Afghanistan  1960     8622466
# 1  Afghanistan  1961     8790140
# 2  Afghanistan  1962     8969047
# 3  Afghanistan  1963     9157465
# 4  Afghanistan  1964     9355514

# %%
df_immigration.head()
# Out:
#                   Country Name Country Code Indicator Name Indicator Code    1960   1961   1962   1963   1964   1965   1966   1967   1968   1969   1970   1971    1972   1973   1974   1975    1976    1977    1978    1979     1980     1981    1982    1983    1984    1985    1986    1987    1988    1989    1990    1991    1992    1993    1994    1995    1996    1997    1998    1999     2000    2001    2002    2003    2004    2005    2006    2007    2008    2009    2010    2011    2012    2013    2014    2015    2016   2017    2018    2019   2020    2021    2022    2023  Unnamed: 68
# 0                        Aruba          ABW  Net migration    SM.POP.NETM    -788   -566   -601   -650   -682   -727   -762  -1066  -1128  -1165  -1189  -1205    -548   -308   -240   -287    -701    -728    -745    -758     -756     -547    -413    -405    -535    -751    -954   -1052    -905    -185     879    1949    1294    1660    1664    1782    1813    1867    1958    2010     1226     566     349     329     326     594     634     672     703     743     501     333     317     315     333     373     405    434     431     420      0     503     152     147          NaN
# 1  Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM -102704 -38646 -56414 -42809  22280   7627   5881  28506  37258 -18615 -12781 -91106 -120416 208461  54059  33607  -60672 -432016  609149  109460   -72573   514791  514670  468187  400951  344728  187193  208800 -230030 -143960   47976 -539801 -208254  250990 -153050 -283365 -719150 -760003 -225429 -471938  -688533 -592931 -531528 -517323 -472255 -568306 -581942 -530023 -438568 -479929 -413050 -712363 -174216  -91530 -414158  151528 -799850 340934  327087  100706 340127  187508 -220428 -989975          NaN
# 2                  Afghanistan          AFG  Net migration    SM.POP.NETM    2606   6109   7016   6681   7079  10695   3563   6824   3333   2029   4458 -12801   -4050  -3030 -20009 -44418  -85430  -83115 -117186 -525413 -1174239 -1998086 -500998 -172797  248224 -208685 -343397 -345535  -56263   18296 -458737   32782 1197329 1149684  315206   52505    4072  -21215    7380  -32400 -1025973 -212872  860349  247317 -269194  250971   57673 -851298  215753  -60602 -167460  384486   68628   18119  233913 -286314 -143049 -71491  -36753    9159 143634 -548784 -647402  -48958          NaN
# 3   Africa Western and Central          AFW  Net migration    SM.POP.NETM    -759 -36991 -31675 -32310 -40403 -11060 -16542  14318   2490 -11263   6280 -86862  -56095 -51583  -1121  -2052 -141841  -65322  -56459  -40641   -94343   -18826   74723 -626026 -251393 -187629 -143659 -125058  -68540  -28470 -482233  -43861   39360 -271392 -117487   96446  -99789  147489  146647 -104687    29309    1062    4172  -72858  -15775 -127048 -213837 -217242 -252742 -245845 -310519 -223577 -509144 -373991 -181414 -247654   50874 -72945 -178068 -270812 -39974 -149585  -81809  327673          NaN
# 4                       Angola          AGO  Net migration    SM.POP.NETM  -40935 -74774 -77265 -78700 -79977 -81111 -82767 -85173 -87730 -90395 -36456   4386   47611  54650  53232  52662   47927   61110   61200   64158    72192    70910   75921   82958   78529   74738   64974   62820   65028   63586   64821   46143   53310   52879   61569   55568   61681   67944   70527   70301    72793   77458   82292   80828   90553   87050   95431  100563  100370  105077  122418  128800  130643  124478   84535   74171   91614  77731   61632   58984   7556   29094    -995    -995          NaN

# %%
df_crime.head(10)
# Out:
#                   Country Name Country Code                              Indicator Name  Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023  Unnamed: 68
# 0                        Aruba          ABW  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     0   NaN   NaN   NaN   NaN     8   NaN   NaN   NaN     2   NaN     4     5     4     2     6     5     3     5     4     4     2     4     6     2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1  Africa Eastern and Southern          AFE  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    15   NaN    10    10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2                  Afghanistan          AFG  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     4     3     4     6   NaN   NaN    10     7     7     7     7     7     4   NaN   NaN          NaN
# 3   Africa Western and Central          AFW  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    13   NaN     8     8   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 4                       Angola          AGO  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     4     5   NaN   NaN     4     4   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5                      Albania          ALB  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     4     6     3     8     8    41    20    17     4     7     7     5     4     5     3     4     3     3     4     5     5     4     5     2     3     2     2     2     2     2   NaN   NaN          NaN
# 6                      Andorra          AND  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     1   NaN   NaN     0     1     0     0     1     0     0     0     0   NaN   NaN   NaN   NaN     3   NaN   NaN   NaN          NaN
# 7                   Arab World          ARB  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     5   NaN     4     4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 8         United Arab Emirates          ARE  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     1     1     1     1     1     1   NaN   NaN   NaN     1     1     0   NaN   NaN          NaN
# 9                    Argentina          ARG  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     8     9     8     6     6     5     5     6     6     6     6     6     7     8     7     6     5     5     5     5     5   NaN   NaN          NaN

# %% [markdown]
# ## 2. Procesamiento y Transformación de Datos

# %% [markdown]
# ### 2.1. Conversión a formato Largo y ordenar por países Dataset Migración y Crímen

# %% [markdown]
# #### 2.1.1. Primero eliminamos columnas que no necesitamos

# %% [markdown]
#         #### Migración México

# %%
# Migración
columnas_a_eliminar = ['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 68']

# Crear una copia del DataFrame sin esas columnas
df_immigration_clean = df_immigration.drop(columns=columnas_a_eliminar)

# Verificar las columnas restantes
print("\nColumnas después de eliminar:")
print(df_immigration_clean.columns.tolist())
# Out:
# Columnas después de eliminar:
# ['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# %% [markdown]
#         #### Crimen en México (Narcotráfico)

# %%
# Crimen
columnas_a_eliminar = ['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 68']

# Crear una copia del DataFrame sin esas columnas
df_crime_clean = df_crime.drop(columns=columnas_a_eliminar)

# Verificar las columnas restantes
print("\nColumnas después de eliminar:")
print(df_crime_clean.columns.tolist())
# Out:
# Columnas después de eliminar:
# ['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# %% [markdown]
# ### 2.1.2 Procedemos con la conversión a formato largo y ordenamos

# %% [markdown]
# #### Mexico Migration

# %%
df_longm = pd.melt(
    df_immigration_clean,
    id_vars=['Country Name'],
    var_name='Year',
    value_name='Net_Migration'
)

# Ordenar el dataframe por país y año
df_longm = df_longm.sort_values(['Country Name', 'Year'])

# Resetear los índices
df_longm = df_longm.reset_index(drop=True)

# Mostrar las primeras filas para verificar la transformación
print("Primeras filas del DataFrame de Migración:")
print(df_longm.head(10))
# Out:
# Primeras filas del DataFrame de Migración:
#   Country Name  Year  Net_Migration
# 0  Afghanistan  1960           2606
# 1  Afghanistan  1961           6109
# 2  Afghanistan  1962           7016
# 3  Afghanistan  1963           6681
# 4  Afghanistan  1964           7079
# 5  Afghanistan  1965          10695
# 6  Afghanistan  1966           3563
# 7  Afghanistan  1967           6824
# 8  Afghanistan  1968           3333
# 9  Afghanistan  1969           2029

# %% [markdown]
# #### Crime Rating

# %%
df_longcrime = pd.melt(
  df_crime_clean,
  id_vars=['Country Name'], 
  var_name='Year',
  value_name='Intentional homicides (per 100,000 people)'
)

# Ordenar el dataframe primero por país y luego por año
df_longcrime = df_longcrime.sort_values(by=['Country Name', 'Year'])

# Resetear los índices para que sean consecutivos
df_longcrime = df_longcrime.reset_index(drop=True)

# Mostrar las primeras filas para verificar la transformación inicial
print("Primeras filas del DataFrame de migración transformado:")
print(df_longcrime.head(10))
# Out:
# Primeras filas del DataFrame de migración transformado:
#   Country Name  Year  Intentional homicides (per 100,000 people)
# 0  Afghanistan  1960                                         NaN
# 1  Afghanistan  1961                                         NaN
# 2  Afghanistan  1962                                         NaN
# 3  Afghanistan  1963                                         NaN
# 4  Afghanistan  1964                                         NaN
# 5  Afghanistan  1965                                         NaN
# 6  Afghanistan  1966                                         NaN
# 7  Afghanistan  1967                                         NaN
# 8  Afghanistan  1968                                         NaN
# 9  Afghanistan  1969                                         NaN

# %% [markdown]
# ### 2.2 Conversion de tipo de datos datasets

# %% [markdown]
# ### Migration

# %%
# Verificar el tipo de datos actual de la columna 'Year'
print(f"Tipo de datos de la columna 'Year': {df_longm['Year'].dtype}")

#Convertir el año a tipo numérico
df_longm['Year'] = pd.to_numeric(df_longm['Year'])

# Verificar que la conversión fue exitosa
print(f"Nuevo tipo de datos de la columna 'Year': {df_longm['Year'].dtype}")

# Mostrar algunos datos
df_longm.head(5)
# Out:
# Tipo de datos de la columna 'Year': object
# Nuevo tipo de datos de la columna 'Year': int64
#   Country Name  Year  Net_Migration
# 0  Afghanistan  1960           2606
# 1  Afghanistan  1961           6109
# 2  Afghanistan  1962           7016
# 3  Afghanistan  1963           6681
# 4  Afghanistan  1964           7079

# %% [markdown]
# #### Crime

# %%
# Verificar el tipo de datos actual de la columna 'Year'
print(f"Tipo de datos de la columna 'Year': {df_longcrime['Year'].dtype}")

#Convertir el año a tipo numérico
df_longcrime['Year'] = pd.to_numeric(df_longcrime['Year'])

# Verificar que la conversión fue exitosa
print(f"Nuevo tipo de datos de la columna 'Year': {df_longcrime['Year'].dtype}")

# Mostrar algunos datos
df_longcrime.head(5)
# Out:
# Tipo de datos de la columna 'Year': object
# Nuevo tipo de datos de la columna 'Year': int64
#   Country Name  Year  Intentional homicides (per 100,000 people)
# 0  Afghanistan  1960                                         NaN
# 1  Afghanistan  1961                                         NaN
# 2  Afghanistan  1962                                         NaN
# 3  Afghanistan  1963                                         NaN
# 4  Afghanistan  1964                                         NaN

# %% [markdown]
# ## 3. Crear un nuevo DataFrame combinando ambos

# %% [markdown]
# #### Migration - World Population

# %%
#Se combinan los dos dataframes utilizando innerjoin
df_combinedmp = pd.merge(
    df_world,
    df_longm [['Country Name', 'Year', 'Net_Migration']],
)

# Verificar el resultado
print("DataFrame Migration combinado:")
print(df_combinedmp.head(10))
# Out:
# DataFrame Migration combinado:
#   Country Name  Year  Population  Net_Migration
# 0  Afghanistan  1960     8622466           2606
# 1  Afghanistan  1961     8790140           6109
# 2  Afghanistan  1962     8969047           7016
# 3  Afghanistan  1963     9157465           6681
# 4  Afghanistan  1964     9355514           7079
# 5  Afghanistan  1965     9565147          10695
# 6  Afghanistan  1966     9783147           3563
# 7  Afghanistan  1967    10010030           6824
# 8  Afghanistan  1968    10247780           3333
# 9  Afghanistan  1969    10494489           2029

# %% [markdown]
# #### Population - Crime

# %%
#Combinación de crímen y world population
df_combinedpc = pd.merge(
    df_world,
    df_longcrime [['Country Name', 'Year', 'Intentional homicides (per 100,000 people)']],
)

# Verificar el resultado
print("DataFrame Migration y Crime combinado:")
print(df_combinedpc.head(10))
# Out:
# DataFrame Migration y Crime combinado:
#   Country Name  Year  Population  Intentional homicides (per 100,000 people)
# 0  Afghanistan  1960     8622466                                         NaN
# 1  Afghanistan  1961     8790140                                         NaN
# 2  Afghanistan  1962     8969047                                         NaN
# 3  Afghanistan  1963     9157465                                         NaN
# 4  Afghanistan  1964     9355514                                         NaN
# 5  Afghanistan  1965     9565147                                         NaN
# 6  Afghanistan  1966     9783147                                         NaN
# 7  Afghanistan  1967    10010030                                         NaN
# 8  Afghanistan  1968    10247780                                         NaN
# 9  Afghanistan  1969    10494489                                         NaN

# %% [markdown]
# #### Crime - migration

# %%
# Combinamos los DataFrames en función de 'Country Name' y 'Year'
df_combinedcm = pd.merge(
    df_longcrime [['Country Name', 'Year', 'Intentional homicides (per 100,000 people)']],
    df_longm[['Country Name', 'Year', 'Net_Migration' ]],
)

# Mostramos las primeras filas del DataFrame combinado
print("Primeras filas del DataFrame combinado:")
print(df_combinedcm.head(10))
# Out:
# Primeras filas del DataFrame combinado:
#   Country Name  Year  Intentional homicides (per 100,000 people)  Net_Migration
# 0  Afghanistan  1960                                         NaN           2606
# 1  Afghanistan  1961                                         NaN           6109
# 2  Afghanistan  1962                                         NaN           7016
# 3  Afghanistan  1963                                         NaN           6681
# 4  Afghanistan  1964                                         NaN           7079
# 5  Afghanistan  1965                                         NaN          10695
# 6  Afghanistan  1966                                         NaN           3563
# 7  Afghanistan  1967                                         NaN           6824
# 8  Afghanistan  1968                                         NaN           3333
# 9  Afghanistan  1969                                         NaN           2029

# %% [markdown]
# #### Crime, Population & Migration

# %%
# Combinar Crime, Population y Migration
df_all_combined = pd.merge(
    df_combinedcm,
    df_world [['Country Name', 'Year', 'Population']],
)

print("Primeras filas del DataFrame combinado:")
print(df_all_combined.head(10))
# Out:
# Primeras filas del DataFrame combinado:
#   Country Name  Year  Intentional homicides (per 100,000 people)  Net_Migration  Population
# 0  Afghanistan  1960                                         NaN           2606     8622466
# 1  Afghanistan  1961                                         NaN           6109     8790140
# 2  Afghanistan  1962                                         NaN           7016     8969047
# 3  Afghanistan  1963                                         NaN           6681     9157465
# 4  Afghanistan  1964                                         NaN           7079     9355514
# 5  Afghanistan  1965                                         NaN          10695     9565147
# 6  Afghanistan  1966                                         NaN           3563     9783147
# 7  Afghanistan  1967                                         NaN           6824    10010030
# 8  Afghanistan  1968                                         NaN           3333    10247780
# 9  Afghanistan  1969                                         NaN           2029    10494489

# %% [markdown]
# ## 4. Identificar Países

# %%
print(df_all_combined['Country Name'].unique()[:280])
# Out:
# ['Afghanistan' 'Africa Eastern and Southern' 'Africa Western and Central'
#  'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Arab World' 'Argentina' 'Armenia' 'Aruba'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'British Virgin Islands' 'Brunei Darussalam' 'Bulgaria' 'Burkina Faso'
#  'Burundi' 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada'
#  'Caribbean small states' 'Cayman Islands' 'Central African Republic'
#  'Central Europe and the Baltics' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Early-demographic dividend'
#  'East Asia & Pacific' 'East Asia & Pacific (IDA & IBRD countries)'
#  'East Asia & Pacific (excluding high income)' 'Ecuador'
#  'Egypt, Arab Rep.' 'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia'
#  'Eswatini' 'Ethiopia' 'Euro area' 'Europe & Central Asia'
#  'Europe & Central Asia (IDA & IBRD countries)'
#  'Europe & Central Asia (excluding high income)' 'European Union'
#  'Faroe Islands' 'Fiji' 'Finland'
#  'Fragile and conflict affected situations' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
#  'Greenland' 'Grenada' 'Guam' 'Guatemala' 'Guinea' 'Guinea-Bissau'
#  'Guyana' 'Haiti' 'Heavily indebted poor countries (HIPC)' 'High income'
#  'Honduras' 'Hong Kong SAR, China' 'Hungary' 'IBRD only'
#  'IDA & IBRD total' 'IDA blend' 'IDA only' 'IDA total' 'Iceland' 'India'
#  'Indonesia' 'Iran, Islamic Rep.' 'Iraq' 'Ireland' 'Isle of Man' 'Israel'
#  'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya' 'Kiribati'
#  "Korea, Dem. People's Rep." 'Korea, Rep.' 'Kosovo' 'Kuwait'
#  'Kyrgyz Republic' 'Lao PDR' 'Late-demographic dividend'
#  'Latin America & Caribbean'
#  'Latin America & Caribbean (excluding high income)'
#  'Latin America & the Caribbean (IDA & IBRD countries)' 'Latvia'
#  'Least developed countries: UN classification' 'Lebanon' 'Lesotho'
#  'Liberia' 'Libya' 'Liechtenstein' 'Lithuania' 'Low & middle income'
#  'Low income' 'Lower middle income' 'Luxembourg' 'Macao SAR, China'
#  'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Mali' 'Malta'
#  'Marshall Islands' 'Mauritania' 'Mauritius' 'Mexico'
#  'Micronesia, Fed. Sts.' 'Middle East & North Africa'
#  'Middle East & North Africa (IDA & IBRD countries)'
#  'Middle East & North Africa (excluding high income)' 'Middle income'
#  'Moldova' 'Monaco' 'Mongolia' 'Montenegro' 'Morocco' 'Mozambique'
#  'Myanmar' 'Namibia' 'Nauru' 'Nepal' 'Netherlands' 'New Caledonia'
#  'New Zealand' 'Nicaragua' 'Niger' 'Nigeria' 'North America'
#  'North Macedonia' 'Northern Mariana Islands' 'Norway' 'Not classified'
#  'OECD members' 'Oman' 'Other small states' 'Pacific island small states'
#  'Pakistan' 'Palau' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru'
#  'Philippines' 'Poland' 'Portugal' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'Puerto Rico' 'Qatar' 'Romania'
#  'Russian Federation' 'Rwanda' 'Samoa' 'San Marino'
#  'Sao Tome and Principe' 'Saudi Arabia' 'Senegal' 'Serbia' 'Seychelles'
#  'Sierra Leone' 'Singapore' 'Sint Maarten (Dutch part)' 'Slovak Republic'
#  'Slovenia' 'Small states' 'Solomon Islands' 'Somalia' 'South Africa'
#  'South Asia' 'South Asia (IDA & IBRD)' 'South Sudan' 'Spain' 'Sri Lanka'
#  'St. Kitts and Nevis' 'St. Lucia' 'St. Martin (French part)'
#  'St. Vincent and the Grenadines' 'Sub-Saharan Africa'
#  'Sub-Saharan Africa (IDA & IBRD countries)'
#  'Sub-Saharan Africa (excluding high income)' 'Sudan' 'Suriname' 'Sweden'
#  'Switzerland' 'Syrian Arab Republic' 'Tajikistan' 'Tanzania' 'Thailand'
#  'Timor-Leste' 'Togo' 'Tonga' 'Trinidad and Tobago' 'Tunisia' 'Turkiye'
#  'Turkmenistan' 'Turks and Caicos Islands' 'Tuvalu' 'Uganda' 'Ukraine'
#  'United Arab Emirates' 'United Kingdom' 'United States'
#  'Upper middle income' 'Uruguay' 'Uzbekistan' 'Vanuatu' 'Venezuela, RB'
#  'Viet Nam' 'Virgin Islands (U.S.)' 'West Bank and Gaza' 'World'
#  'Yemen, Rep.' 'Zambia' 'Zimbabwe']

# %% [markdown]
# ## 5. Análisis Migratorio en México basado en Violencia Criminal (Homicidios 2000 - 2023)

# %%
mexico = df_combinedcm[df_combinedcm['Country Name'] == 'Mexico']

#Filtrar el período de 2000 a 2023
guerra_narco = mexico[(mexico['Year'] >= 1980) & (mexico['Year'] <= 2025)]

#Verificar el periodo correcto
print("Datos de México de 2000 a 2023:")
print(guerra_narco.head(20))
# Out:
# Datos de México de 2000 a 2023:
#       Country Name  Year  Intentional homicides (per 100,000 people)  Net_Migration
# 10068       Mexico  1980                                         NaN        -252177
# 10069       Mexico  1981                                         NaN        -361791
# 10070       Mexico  1982                                         NaN        -382048
# 10071       Mexico  1983                                         NaN        -402937
# 10072       Mexico  1984                                         NaN        -425467
# 10073       Mexico  1985                                         NaN        -445447
# 10074       Mexico  1986                                         NaN        -451756
# 10075       Mexico  1987                                         NaN        -415521
# 10076       Mexico  1988                                         NaN        -374544
# 10077       Mexico  1989                                         NaN        -386467
# 10078       Mexico  1990                                          18        -321764
# 10079       Mexico  1991                                          18        -326691
# 10080       Mexico  1992                                          20        -344313
# 10081       Mexico  1993                                          19        -358039
# 10082       Mexico  1994                                          18        -354573
# 10083       Mexico  1995                                          17        -340091
# 10084       Mexico  1996                                          16        -343399
# 10085       Mexico  1997                                          15        -340546
# 10086       Mexico  1998                                          14        -321385
# 10087       Mexico  1999                                          13        -328773

# %% [markdown]
# ## 6. Analisis migratiorio basado en violencia criminal

# %% [markdown]
# #### 6.1 Tabla de visualizaci{on}

# %%
# Verificar los valores negativos en Net_Migration
negativos = guerra_narco[guerra_narco['Net_Migration'] < 0]
print("Valores negativos en Net_Migration:")
print(negativos)

# Visualizar la tendencia de Net_Migration a lo largo de los años
plt.figure(figsize=(10, 6))
sns.lineplot(data=guerra_narco, x='Year', y='Net_Migration', marker='o')
plt.title('Tendencia de la Migración Neta en México (1999-2021)')
plt.xlabel('Año')
plt.ylabel('Migración Neta')
plt.grid(True)
plt.show()
# Out:
# Valores negativos en Net_Migration:
#       Country Name  Year  Intentional homicides (per 100,000 people)  Net_Migration
# 10068       Mexico  1980                                         NaN        -252177
# 10069       Mexico  1981                                         NaN        -361791
# 10070       Mexico  1982                                         NaN        -382048
# 10071       Mexico  1983                                         NaN        -402937
# 10072       Mexico  1984                                         NaN        -425467
# 10073       Mexico  1985                                         NaN        -445447
# 10074       Mexico  1986                                         NaN        -451756
# 10075       Mexico  1987                                         NaN        -415521
# 10076       Mexico  1988                                         NaN        -374544
# 10077       Mexico  1989                                         NaN        -386467
# 10078       Mexico  1990                                          18        -321764
# 10079       Mexico  1991                                          18        -326691
# 10080       Mexico  1992                                          20        -344313
# 10081       Mexico  1993                                          19        -358039
# 10082       Mexico  1994                                          18        -354573
# 10083       Mexico  1995                                          17        -340091
# 10084       Mexico  1996                                          16        -343399
# 10085       Mexico  1997                                          15        -340546
# 10086       Mexico  1998                                          14        -321385
# 10087       Mexico  1999                                          13        -328773
# 10088       Mexico  2000                                          11        -356433
# 10089       Mexico  2001                                          10        -378348
# 10090       Mexico  2002                                          10        -379812
# 10091       Mexico  2003                                          10        -369183
# 10092       Mexico  2004                                           9        -346912
# 10093       Mexico  2005                                           9        -310278
# 10094       Mexico  2006                                          10        -244140
# 10095       Mexico  2007                                           8        -105524
# 10096       Mexico  2008                                          13         -50347
# 10097       Mexico  2009                                          18         -30809
# 10098       Mexico  2010                                          23         -40845
# 10099       Mexico  2011                                          24         -37826
# 10100       Mexico  2012                                          22        -128485
# 10101       Mexico  2013                                          20        -120058
# 10102       Mexico  2014                                          17        -228816
# 10103       Mexico  2015                                          17        -291044
# 10104       Mexico  2016                                          20        -304472
# 10105       Mexico  2017                                          26        -227499
# 10106       Mexico  2018                                          30        -175356
# 10107       Mexico  2019                                          29        -169628
# 10108       Mexico  2020                                          29        -147456
# 10109       Mexico  2021                                          28        -122791
# 10110       Mexico  2022                                         NaN        -108438
# 10111       Mexico  2023                                         NaN        -101044

# %% [markdown]
# #### 6.2 Correlación de crimen con migración

# %%
# Calcular correlación
correlacion = guerra_narco[['Net_Migration', 'Intentional homicides (per 100,000 people)']].corr()
print(f"Correlación entre Migración Neta y Homicidios Intencionales: ")
print(correlacion)

# Extraer el coeficiente específico de correlación
coef_corr = correlacion.iloc[0, 1]  # Valor en la posición [0,1] de la matriz
print(f"Coeficiente de correlación: {coef_corr:.3f}")

# Matriz de correlación con todas las variables numéricas
matriz_corr = guerra_narco.select_dtypes(include='number').corr()
print("\nMatriz de correlación completa:")
print(matriz_corr)
# Out:
# Correlación entre Migración Neta y Homicidios Intencionales:
#                                             Net_Migration  Intentional homicides (per 100,000 people)
# Net_Migration                                           1                                           0
# Intentional homicides (per 100,000 people)              0                                           1
# Coeficiente de correlación: 0.471
#
# Matriz de correlación completa:
#                                             Year  Intentional homicides (per 100,000 people)  Net_Migration
# Year                                           1                                           1              1
# Intentional homicides (per 100,000 people)     1                                           1              0
# Net_Migration                                  1                                           0              1

# %% [markdown]
# #### 6.3. Visualización de la gráfica de la correlación

# %%
# Gráfico de dispersión para mostrar la relación
plt.figure(figsize=(12, 8))

# Crear el gráfico de dispersión
scatter = sns.scatterplot(data=guerra_narco, 
                x='Intentional homicides (per 100,000 people)', 
                y='Net_Migration')

# Añadir línea de tendencia
sns.regplot(data=guerra_narco, 
            x='Intentional homicides (per 100,000 people)', 
            y='Net_Migration',
            scatter=False, 
            line_kws={"color":"red"})

# Crear un diccionario para eventos importantes
# Será necesario localizar las coordenadas (tasa de homicidios, migración neta) para cada año
eventos = {
    # Terremotos
    2017: "Terremoto 2017",
    
    # Cambios de gobierno
    2006: "Inicio Felipe Calderón\nGuerra contra narco", 
    2012: "Inicio Peña Nieto", 
    2018: "Inicio AMLO"
}

# Añadir anotaciones para cada evento
for year, label in eventos.items():
    if year in guerra_narco['Year'].values:
        # Obtener los valores x,y para este año
        punto = guerra_narco[guerra_narco['Year'] == year]
        x = punto['Intentional homicides (per 100,000 people)'].values[0]
        y = punto['Net_Migration'].values[0]
        
        # Añadir anotación
        plt.annotate(label, 
                     xy=(x, y),
                     xytext=(10, 10),
                     textcoords='offset points',
                     arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.2'),
                     bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.7))

# Añadir eventos fuera del rango temporal como nota
plt.figtext(0.5, 0.01, 
           "Nota: El terremoto de 1985 y la crisis económica de los 90s están fuera del rango temporal de los datos (1999-2021)",
           ha="center", fontsize=10, bbox={"facecolor":"orange", "alpha":0.2, "pad":5})

plt.title('Relación entre Tasa de Homicidios y Migración Neta')
plt.xlabel('Homicidios Intencionales (por 100,000 habitantes)')
plt.ylabel('Migración Neta')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Crear dos ejes Y para visualizar ambas variables
fig, ax1 = plt.subplots(figsize=(15, 8))

# Eje Y1: Migración Neta
color = 'tab:blue'
ax1.set_xlabel('Año')
ax1.set_ylabel('Migración Neta', color=color)
ax1.plot(guerra_narco['Year'], guerra_narco['Net_Migration'], color=color, marker='o')
ax1.tick_params(axis='y', labelcolor=color)

# Eje Y2: Tasa de Homicidios
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Homicidios (por 100,000)', color=color)
ax2.plot(guerra_narco['Year'], guerra_narco['Intentional homicides (per 100,000 people)'], 
         color=color, marker='s')
ax2.tick_params(axis='y', labelcolor=color)

# Eventos importantes: cambios presidenciales y terremotos
eventos = {
    # Presidentes desde 1980
    1985: "Terremoto CDMX",
    1988: "Salinas",
    1994: "Zedillo\nCrisis del 94",
    2000: "Fox",
    2006: "Calderón\nGuerra contra narco",
    2012: "Peña Nieto",
    2017: "Terremoto\nCDMX/Chiapas",
    2018: "AMLO",
    2020: "Pandemia\nCOVID-19"
}

# Añadir líneas verticales y etiquetas para cada evento
min_y1, max_y1 = ax1.get_ylim()
altura_texto = min_y1 + (max_y1 - min_y1) * 0.9  # Posición para las etiquetas

for year, label in eventos.items():
    if year in guerra_narco['Year'].values or (year >= min(guerra_narco['Year']) and year <= max(guerra_narco['Year'])):
        # Verificar si el año está cerca de algún año en los datos (para evitar errores)
        # Añadir línea vertical punteada
        ax1.axvline(x=year, color='green', linestyle='--', alpha=0.7)
        
        # Añadir etiqueta
        ax1.text(year, altura_texto, label, rotation=90, 
                verticalalignment='top', horizontalalignment='right',
                bbox=dict(facecolor='yellow', alpha=0.5, pad=3))

# Añadir leyenda para las líneas
ax1.plot([], [], color='tab:blue', marker='o', label='Migración Neta')
ax1.plot([], [], color='tab:red', marker='s', label='Tasa de Homicidios')
ax1.legend(loc='upper left')

# Ajustar título para reflejar el rango completo de años
min_year = min(guerra_narco['Year'])
max_year = max(guerra_narco['Year'])
plt.title(f'Tendencias de Migración Neta y Homicidios en México ({min_year}-{max_year})\ncon eventos históricos importantes', fontsize=14)

# Mejorar visual
plt.grid(True, alpha=0.3)
fig.tight_layout(rect=[0, 0.03, 1, 0.97])  # Dejar espacio para la nota

plt.show()
