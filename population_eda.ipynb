# %% [markdown]
# ## EDA de la población mundial por país

# %% [markdown]
# <h3>Importamos librerias para trabajar con datos</h3>

# %%
import pandas as pd
import numpy as np

# Importamos librerias para visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Configuramos las gráficas
plt.style.use('seaborn-v0_8')

# %% [markdown]
# <h3> Cargar el dataset </h3>

# %%
df = pd.read_csv('data/world_population.csv')

# Mostrar cuantas filas y columnas tiene el DataFrame
print(f"El DataFrame tiene {df.shape[0]} filas y {df.shape[1]} columnas.")
# Out:
# El DataFrame tiene 266 filas y 64 columnas.

# %% [markdown]
# <h3> Información del dataframe </h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 64 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   1960          266 non-null    float64
#  2   1961          266 non-null    float64
#  3   1962          266 non-null    float64
#  4   1963          266 non-null    float64
#  5   1964          266 non-null    float64
#  6   1965          266 non-null    float64
#  7   1966          266 non-null    float64
#  8   1967          266 non-null    float64
#  9   1968          266 non-null    float64
#  10  1969          266 non-null    float64
#  11  1970          266 non-null    float64
#  12  1971          266 non-null    float64
#  13  1972          266 non-null    float64
#  14  1973          266 non-null    float64
#  15  1974          266 non-null    float64
#  16  1975          266 non-null    float64
# ...

# %% [markdown]
# <h3> Mostrar las primeras filas del DataFrame para entender su estructura </h3>

# %%
df.head()
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
# 2    9157465.0    9355514.0    9565147.0    9783147.0   10010030.0
# 3  103667517.0  105959979.0  108336203.0  110798486.0  113319950.0
# 4    5599827.0    5673199.0    5736582.0    5787044.0    5827503.0
#
#           1968  ...         2013         2014         2015         2016  \
# ...

# %% [markdown]
# <h3> Calcular estadísticas descriptivas del DataFrame </h3>

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02
# mean   1.172860e+08  1.188956e+08  1.210661e+08  1.237484e+08  1.264530e+08
# std    3.681528e+08  3.726814e+08  3.793723e+08  3.880372e+08  3.967440e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.191432e+05  5.299130e+05  5.416058e+05  5.539315e+05  5.669115e+05
# 50%    3.850405e+06  3.950443e+06  4.049641e+06  4.167192e+06  4.281604e+06
# 75%    2.739186e+07  2.812822e+07  2.889649e+07  2.968239e+07  3.046628e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02
# mean   1.291965e+08  1.320558e+08  1.349134e+08  1.378513e+08  1.408944e+08
# ...

# %% [markdown]
# <p> Nota: Los datos pueden parecer exagerados, pero hay que tener en cuenta que también hay agrupaciones regionales, continentales e incluso la mundial en la lista </p>

# %% [markdown]
# <div>
#      <h3>
# Transformación de Datos de Formato Ancho a FormatoLargo
#      </h3>
#      <p classs="font-size: 10px">
#      Este paso es crucial en nuestro análisis
#      exploratorioporque reorganizará los datos para facilitar
#      la visualización de tendencias temporales y permitirnos
#      realizar análisis más efectivos sobre la evolución de la
#      población mundial.
#      </p>
#  </div>

# %%
df_long = pd.melt(
  df,
  id_vars=['Country Name'], 
  var_name='Year',
  value_name='Population'
)

# Convertir el año a tipo numérico, actualmente es string al ser el nombre de las columnas
df_long['Year'] = pd.to_numeric(df_long['Year'])

# Mostrar las primera filas para verificar la transformación
df_long.head((20))

# Información básica del nuevo dataframe
print("\nInformación del dataframe en formato largo:")
print(f"Dimensiones: {df_long.shape}")
print(df_long.info())
# Out:
# Información del dataframe en formato largo:
# Dimensiones: (16758, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16758 entries, 0 to 16757
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  16758 non-null  object
#  1   Year          16758 non-null  int64
#  2   Population    16758 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 392.9+ KB
# None
